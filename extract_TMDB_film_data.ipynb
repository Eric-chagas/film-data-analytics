# %% [markdown]
# # Extração de dados do TMDB (The Movie Database)
# ---
# 27/09/2025
#
# Este notebook tem como objetivo construir um dataset de filmes utilizando a API do The Movie Database (TMDB). O processo é realizado em duas etapas interligadas:
# 1. A primeira etapa é a extração dos dados de **índice** dos filmes a partir do endpoint `/discover/movie`
# 2. A segunda etapa consiste em uma série de requisições para o endpoint `/movie/{movie_id}`, que retorna os dados detalhados de cada filme
#
# ###### Todos os endpoints utilizados nessa extração estão detalhados na [documentação oficial da API do TMDB](https://developer.themoviedb.org/reference/intro/getting-started)

# %%
import requests
import json
import time
import pandas as pd
from os import environ as env
from concurrent.futures import ThreadPoolExecutor, as_completed


# API credentials config -----------------------------------------------------------------------------------------------------
API_AUTH_CONFIG = {
    "tmdb_api_token": env.get("TMDB_API_TOKEN") or "tmdb_api_token_default",
    "tmdb_api_key": env.get("TMDB_API_KEY") or "tmdb_api_key_default"
}

# Api rate limit config
MAX_REQUESTS_PER_SECOND = 50
MIN_TIME_PER_REQUEST = 1.0 / MAX_REQUESTS_PER_SECOND

# API URLs config -----------------------------------------------------------------------------------------------------
index_url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

# Pandas configs
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Passo 1. Requisição dos dados de índice dos filmes
#
# | Componente | Detalhe | Finalidade |
# | :--- | :--- | :--- |
# | **Endpoint** | **`/discover/movie`** | Obtém a lista de filmes que se enquadram em critérios amplos (ex: por popularidade, gênero, ano de lançamento). |
# | **Filtros** | (Especifique os parâmetros usados, ex: `with_genres`, `sort_by`, `page`) | Define o universo de filmes a ser coletado. |
# | **Output Crucial** | **`id`** (Identificador único do filme) | O ID é o dado chave que será utilizado na próxima etapa. |

# %%
headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {API_AUTH_CONFIG['tmdb_api_token']}"
}

# Requests configs
num_total_pages = 30

# Function for single index page request
def fetch_index(page):
    index_base_url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={page}&sort_by=popularity.desc"
    
    params = {
        "api_key": API_AUTH_CONFIG['tmdb_api_key'],
    }
    
    index_response = requests.get(index_base_url, params=params)
    index_string = index_response.content.decode('utf-8')
    index_json = json.loads(index_string)
    
    print(f"Fetched: {index_json['page']}")
    
    return index_json

# Function for parallel index page requests
def fetch_index_parallel(num_total_pages, max_workers=5):
    index_complete_result = []
    pages_to_request = range(1, num_total_pages + 1)
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {}
        
        for page in pages_to_request:
            start_time = time.time()
            
            future = executor.submit(fetch_index, page)
            futures[future] = page
            
            time_spent = time.time() - start_time
            sleep_time = MIN_TIME_PER_REQUEST - time_spent
            
            if sleep_time > 0:
                time.sleep(sleep_time)
        
        for future in as_completed(futures):
            try:
                index_complete_result.append(future.result())
            except Exception as e:
                mid = futures[future]
                print(f"Erro ao buscar página de índice {mid}: {e}")
    return index_complete_result

index_page_data = fetch_index_parallel(num_total_pages)
print(f"\nTotal de páginas buscadas: {len(index_page_data)}")
# Out:
# Fetched: 2
# Fetched: 1
# Fetched: 3
# Fetched: 4
# Fetched: 5
# Fetched: 7
# Fetched: 6
# Fetched: 8
# Fetched: 9
# Fetched: 10
# Fetched: 11
# Fetched: 12
# Fetched: 13
# Fetched: 14
# Fetched: 15
# Fetched: 16
# Fetched: 17
# Fetched: 18
# Fetched: 19
# Fetched: 20
# Fetched: 21
# Fetched: 22
# Fetched: 24
# Fetched: 23
# Fetched: 25
# Fetched: 27
# Fetched: 26
# Fetched: 29
# Fetched: 28
# Fetched: 30
#
# Total de páginas buscadas: 30

# %%
# print(f'Total pages: {index_page_data['results']}')
# print(f'Total results: {len(index_page_data)}')
index_results_list = [page['results'] for page in index_page_data]
final_index_list = []
for index_page in index_results_list:
    final_index_list.extend(index_page)
    
print(f"Finalizado extend da lista de indices com {len(final_index_list)} resultados.")
# Out:
# Finalizado extend da lista de indices com 600 resultados.

# %%
movie_index_df = pd.DataFrame(final_index_list)

# print(movie_index_df)
print(len(movie_index_df))

# print(movie_index_df.columns)
# Out:
# 600

# %% [markdown]
# ### Passo 2: Detalhamento Individual dos Filmes
#
# | Componente | Detalhe | Finalidade |
# | :--- | :--- | :--- |
# | **Endpoint** | **`/movie/{movie_id}`** | Realiza uma consulta específica para cada `id` obtido no Passo 1. |
# | **Processo** | O código **itera** sobre a lista de IDs extraída. | Garante que cada filme tenha seus dados detalhados coletados. |
# | **Output Final** | Dados detalhados (`budget`, `revenue`, `runtime`, `production_companies`, etc.). | Cria o *dataset* final para a análise. |

# %%
# Set current search movie id list from index table response
movie_ids = movie_index_df['id'].tolist()

# Function for single movie request
def fetch_film(movie_id):
    detail_url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    
    params = {
        "api_key": API_AUTH_CONFIG['tmdb_api_key'],
        # "append_to_response": "genres"
    }
    
    movie_detail_response = requests.get(detail_url, params=params)
    movie_detail_string = movie_detail_response.content.decode('utf-8')
    movie_detail_json = json.loads(movie_detail_string)
    
    print(f"Fetched: {movie_detail_json['title']}")
    
    return movie_detail_json

# Function for parallel movie detail requests
def fetch_movies_parallel(movie_ids, max_workers=5):
    movie_detail_results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {}
        
        for movie in movie_ids:
            start_time = time.time()
            
            future = executor.submit(fetch_film, movie)
            futures[future] = movie
            
            time_spent = time.time() - start_time
            sleep_time = MIN_TIME_PER_REQUEST - time_spent
            
            if sleep_time > 0:
                time.sleep(sleep_time)
        
        for future in as_completed(futures):
            try:
                movie_detail_results.append(future.result())
            except Exception as e:
                mid = futures[future]
                print(f"Erro ao buscar filme {mid}: {e}")
    return movie_detail_results

movie_detail_data = fetch_movies_parallel(movie_ids)
print(f"\nTotal de filmes buscados: {len(movie_detail_data)}")
# Out:
# Fetched: Karate Kid: Legends
# Fetched: Sinners
# Fetched: Holy Cow
# Fetched: Sorority
# Fetched: Moana 2
# Fetched: Deadpool & Wolverine
# Fetched: Bring Her Back
# Fetched: Stockholm Bloodbath
# Fetched: The Long Walk
# Fetched: Locos de amor, mi primer amor
# Fetched: My Fault: London
# Fetched: Thunderbolts*
# Fetched: The Smashing Machine
# Fetched: The Conjuring: The Devil Made Me Do It
# Fetched: Dracula: A Love Tale
# Fetched: Donde tú quieras
# Fetched: Harry Potter and the Philosopher's Stone
# Fetched: I Know What You Did Last Summer
# Fetched: Get Fast
# Fetched: A Minecraft Movie
# Fetched: The Conjuring: Last Rites
# Fetched: The Lost Princess
# Fetched: The Toxic Avenger Unrated
# Fetched: Marco
# Fetched: Demon Slayer: Kimetsu no Yaiba Infinity Castle
# Fetched: Holy Night: Demon Hunters
# Fetched: War of the Worlds
# Fetched: Play Dirty
# Fetched: Primitive War
# Fetched: The Fantastic 4: First Steps
# Fetched: Fight Another Day
# Fetched: Mantis
# Fetched: HIM
# Fetched: Prisoner of War
# Fetched: The Lost Bus
# Fetched: Django Undisputed
# Fetched: One Battle After Another
# Fetched: KPop Demon Hunters
# Fetched: Superman
# Fetched: Assassin
# Fetched: Avatar: The Way of Water
# Fetched: Putin
# Fetched: Final Destination Bloodlines
# Fetched: Downton Abbey: The Grand Finale
# Fetched: Gunman
# Fetched: Humane
# Fetched: Red Sonja
# Fetched: 28 Years Later
# Fetched: Striking Rescue
# Fetched: Our Fault
# Fetched: M3GAN 2.0
# Fetched: The Avengers
# Fetched: Mantis
# Fetched: St. Vierja Academy
# Fetched: Corpse Bride
# Fetched: Ne Zha
# Fetched: All of You
# Fetched: The Thing Behind The Door
# Fetched: As Good as Dead
# Fetched: The Conjuring
# Fetched: My Fault
# Fetched: Lilo & Stitch
# Fetched: The Day the Earth Blew Up: A Looney Tunes Movie
# Fetched: The Naked Gun
# Fetched: Freakier Friday
# Fetched: Ne Zha 2
# Fetched: Together
# Fetched: Caramelo
# Fetched: Ice Road: Vengeance
# Fetched: Stay
# Fetched: Ruth & Boaz
# Fetched: Possession Street
# Fetched: The Ugly Stepsister
# Fetched: Ballerina
# Fetched: French Lover
# Fetched: Interstellar
# Fetched: Laila
# Fetched: Your Fault
# Fetched: Elio
# Fetched: Caught Stealing
# Fetched: Valiant One
# Fetched: Jurassic Triangle
# Fetched: Rumpelstiltskin
# Fetched: xXx
# Fetched: How to Train Your Dragon
# Fetched: Weapons
# Fetched: Mission: Impossible - The Final Reckoning
# Fetched: Chainsaw Man - The Movie: Reze Arc
# Fetched: Jurassic World Rebirth
# Fetched: F1
# Fetched: Nobody 2
# Fetched: TRON: Ares
# Fetched: Steve
# Fetched: Maintenance Required
# Fetched: Compulsion
# Fetched: Bloody Axe Wound
# Fetched: The Bad Guys 2
# Fetched: Living in Two Houses
# Fetched: The Man in My Basement
# Fetched: Aztec Batman: Clash of Empires
# Fetched: The Gorge
# Fetched: Good Boy
# Fetched: 365 Days: This Day
# Fetched: The Shawshank Redemption
# Fetched: The Accountant²
# Fetched: The Good Luck
# Fetched: The Godfather
# Fetched: Detective Dee: The Four Heavenly Kings
# Fetched: Swiped
# Fetched: The Conjuring 2
# Fetched: Coraline
# Fetched: Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train
# Fetched: Sonic the Hedgehog 3
# Fetched: Despicable Me 4
# Fetched: The Wrong Paris
# Fetched: The Ritual
# Fetched: My Freaky Family
# Fetched: The Hacienda: Return of the Damned
# Fetched: The Hobbit: The Battle of the Five Armies
# Fetched: The Nightmare Before Christmas
# Fetched: The Balloonist
# Fetched: Coco
# Fetched: Smurfs
# Fetched: Kaiju No. 8: Mission Recon
# Fetched: Oh, Hi!
# Fetched: Kalakal
# Fetched: Eenie Meanie
# Fetched: A Working Man
# Fetched: Avengers: Infinity War
# Fetched: The Substance
# Fetched: The Dark Knight
# Fetched: TRON: Legacy
# Fetched: V/H/S/HALLOWEEN
# Fetched: Love Untangled
# Fetched: Legends of the Condor Heroes: The Gallants
# Fetched: Avatar: Fire and Ash
# Fetched: Night Carnage
# Fetched: Inside Out 2
# Fetched: Wicked
# Fetched: Heads of State
# Fetched: The Nightmare Before Christmas
# Fetched: Predator: Badlands
# Fetched: Porn in the Hood
# Fetched: Avatar
# Fetched: The Shadow's Edge
# Fetched: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Fetched: Osiris
# Fetched: Maa
# Fetched: La vecina de al lado
# Fetched: The Lord of the Rings: The Fellowship of the Ring
# Fetched: The Map That Leads to You
# Fetched: Los cantos de Ekai
# Fetched: The Incredibles
# Fetched: Parasite
# Fetched: Fast X
# Fetched: Creation of the Gods II: Demon Force
# Fetched: The Family Plan
# Fetched: A Line of Fire
# Fetched: Hostile Takeover
# Fetched: Highest 2 Lowest
# Fetched: William Tell
# Fetched: Black Phone 2
# Fetched: Inception
# Fetched: Trust
# Fetched: Spider-Man: No Way Home
# Fetched: Venom: The Last Dance
# Fetched: The Maze Runner
# Fetched: Toy Story
# Fetched: Alien: Romulus
# Fetched: Captain America: Brave New World
# Fetched: Fifty Shades of Grey
# Fetched: Harry Potter and the Goblet of Fire
# Fetched: Fight Club
# Fetched: Road House
# Fetched: Dolce... calda Lisa
# Fetched: Kung Fu Panda 4
# Fetched: Baltimore
# Fetched: Rockstar: DUKI from the End of the World
# Fetched: Titanic
# Fetched: Harry Potter and the Chamber of Secrets
# Fetched: Materialists
# Fetched: The Pickup
# Fetched: Dead Bride
# Fetched: Clown in a Cornfield
# Fetched: Anaconda
# Fetched: Zootopia 2
# Fetched: Predator: Killer of Killers
# Fetched: Dangerous Animals
# Fetched: Kantara: Chapter 1
# Fetched: Nobody
# Fetched: Rosie Dixon - Night Nurse
# Fetched: The Lord of the Rings: The Return of the King
# Fetched: The Wild Robot
# Fetched: Shrek
# Fetched: The Black Phone
# Fetched: Mufasa: The Lion King
# Fetched: Kraven the Hunter
# Fetched: Twilight
# Fetched: Harry Potter and the Prisoner of Azkaban
# Fetched: Companion
# Fetched: Unknown Number: The High School Catfish
# Fetched: The Wolf of Wall Street
# Fetched: How I Became a Gangster
# Fetched: Splitsville
# Fetched: After
# Fetched: Spider-Man: Across the Spider-Verse
# Fetched: Iron Man 2
# Fetched: Conjuring the Cult
# Fetched: God's Not Dead: In God We Trust
# Fetched: Pleasure
# Fetched: Lubuk
# Fetched: Tron
# Fetched: The Home
# Fetched: The Amateur
# Fetched: Adulthood
# Fetched: Top Gun: Maverick
# Fetched: Kakushigoto Theatrical Edition
# Fetched: The Veteran
# Fetched: American Sweatshop
# Fetched: Below Her Mouth
# Fetched: Flow
# Fetched: Zootopia
# Fetched: Pirates of the Caribbean: The Curse of the Black Pearl
# Fetched: Pirates of the Caribbean: On Stranger Tides
# Fetched: Lookout
# Fetched: The Woman in the Line
# Fetched: The Suicide Squad
# Fetched: Dirty Ice Cream
# Fetched: Fall for Me
# Fetched: The Super Mario Bros. Movie
# Fetched: Spider-Man: Homecoming
# Fetched: Dune
# Fetched: Gladiator II
# Fetched: The Partisan
# Fetched: John Wick: Chapter 4
# Fetched: Pirates of the Caribbean: Dead Man's Chest
# Fetched: The Island of Lost Girls
# Fetched: Rob1n
# Fetched: Fifty Shades Freed
# Fetched: Harry Potter and the Order of the Phoenix
# Fetched: Gladiator II
# Fetched: Dune
# Fetched: John Wick: Chapter 4
# Fetched: Iron Man 3
# Fetched: Pinball: The Man Who Saved the Game
# Fetched: Fifty Shades Freed
# Fetched: Night Nurse
# Fetched: Taming The Younger Sister-in-Law
# Fetched: Barbie
# Fetched: Oppenheimer
# Fetched: Elemental
# Fetched: Harry Potter and the Deathly Hallows: Part 2
# Fetched: Demon Slayer: Kimetsu no Yaiba — Sibling's Bond
# Fetched: Tell Me What You Want
# Fetched: The Island of Lost Girls
# Fetched: The Ministry of Ungentlemanly Warfare
# Fetched: Big Hero 6
# Fetched: The Bad Guys
# Fetched: Terrifier 3
# Fetched: Alien
# Fetched: The Hobbit: An Unexpected Journey
# Fetched: Gabby's Dollhouse: The Movie
# Fetched: Red One
# Fetched: Incredibles 2
# Fetched: The Matrix
# Fetched: Fabula
# Fetched: Inglourious Basterds
# Fetched: The Strangers: Chapter 2
# Fetched: Dead Again
# Fetched: Mission: Impossible - Dead Reckoning Part One
# Fetched: Dune: Part Two
# Fetched: Harry Potter and the Half-Blood Prince
# Fetched: The Batman
# Fetched: Doctor Strange in the Multiverse of Madness
# Fetched: The Beekeeper
# Fetched: Harami
# Fetched: Mother-in-law in Love With Son-in-law 4
# Fetched: Omniscient Reader: The Prophecy
# Fetched: Spirited Away
# Fetched: Warfare
# Fetched: Warfare
# Fetched: Rob1n
# Fetched: The Idea of You
# Fetched: The Garfield Movie
# Fetched: Se7en
# Fetched: The Batman
# Fetched: She Said Maybe
# Fetched: The Nun
# Fetched: Twittering Birds Never Fly: The Clouds Gather
# Fetched: Snow White
# Fetched: Ode to Joy
# Fetched: In the Sub for Love
# Fetched: Avengers: Endgame
# Fetched: Fury
# Fetched: Psycho
# Fetched: Spider-Man: Into the Spider-Verse
# Fetched: Pulp Fiction
# Fetched: Green Book
# Fetched: Solo Leveling -ReAwakening-
# Fetched: Monsters, Inc.
# Fetched: Solo Leveling -ReAwakening-
# Fetched: Anora
# Fetched: Avengers: Endgame
# Fetched: Se7en
# Fetched: Alien
# Fetched: Same Day with Someone
# Fetched: Ratatouille
# Fetched: Babygirl
# Fetched: Sexy Oral: Uwakina Kuchibiru
# Fetched: 9 Songs
# Fetched: Shadow of God
# Fetched: Furiosa: A Mad Max Saga
# Fetched: Another Training
# Fetched: London Calling
# Fetched: The Next 365 Days
# Fetched: Wicked: For Good
# Fetched: Nosferatu
# Fetched: Green Chair
# Fetched: Psycho
# Fetched: Spider-Man: Far From Home
# Fetched: Afterburn
# Fetched: Fury
# Fetched: Wonder Woman
# Fetched: 28 Days Later
# Fetched: Prisoners
# Fetched: Beasts Cage
# Fetched: Anyone But You
# Fetched: Flight Risk
# Fetched: The Fifth Element
# Fetched: Bride Hard
# Fetched: Troy
# Fetched: Frozen
# Fetched: Gold Rush Gang
# Fetched: Kantara
# Fetched: Spider-Man 3
# Fetched: The Heaven of Animals
# Fetched: Harami
# Fetched: Shrek 2
# Fetched: Kogaloak : The Ghastly Village
# Fetched: The Lion King
# Fetched: Heaven's Gate Boksangsa Temple
# Fetched: The Twilight Saga: New Moon
# Fetched: Lego Disney Princess: Villains Unite
# Fetched: Opus
# Fetched: Toy Story 2
# Fetched: Taken
# Fetched: Inside Out
# Fetched: Inspector Zende
# Fetched: Madharaasi
# Fetched: Dongji Rescue
# Fetched: Van Gogh by Vincent
# Fetched: Kiss and Kill
# Fetched: The Green Mile
# Fetched: Good Will Hunting
# Fetched: White Chicks
# Fetched: Batman v Superman: Dawn of Justice
# Fetched: Shrek 2
# Fetched: Guardians of the Galaxy Vol. 2
# Fetched: Cinderella
# Fetched: My Oxford Year
# Fetched: Dora and the Search for Sol Dorado
# Fetched: Belyas
# Fetched: Penguins of Madagascar
# Fetched: Wrath of Man
# Fetched: Pirates of the Caribbean: At World's End
# Fetched: Homefront
# Fetched: Death of a Unicorn
# Fetched: The Lucky One
# Fetched: Guardians of the Galaxy Vol. 3
# Fetched: Homo Argentum
# Fetched: Avengers: Age of Ultron
# Fetched: Samurai Fury
# Fetched: The Flash
# Fetched: Levels
# Fetched: Favorite Concubine
# Fetched: Batman v Superman: Dawn of Justice
# Fetched: The Lion King
# Fetched: Happy Gilmore 2
# Fetched: Teenage Mutant Ninja Turtles
# Fetched: The Handmaiden
# Fetched: Batman Begins
# Fetched: Paprika
# Fetched: Love Lies Bleeding
# Fetched: Gladiator
# Fetched: Popeye's Revenge
# Fetched: Kiskisan
# Fetched: The Nun
# Fetched: In the Lost Lands
# Fetched: Top Gun
# Fetched: Shang-Chi and the Legend of the Ten Rings
# Fetched: Terminator 2: Judgment Day
# Fetched: Ligaw
# Fetched: Relyebo
# Fetched: Apocalypse Z: The Beginning of the End
# Fetched: Triangle
# Fetched: A Big Bold Beautiful Journey
# Fetched: Blade Runner 2049
# Fetched: Toy Story 3
# Fetched: Star Wars
# Fetched: Meet the Leroys
# Fetched: A Serbian Film
# Fetched: Hanna D: The Girl from Vondel Park
# Fetched: Scream
# Fetched: Sitaare Zameen Par
# Fetched: You Are the Apple of My Eye
# Fetched: Finding Nemo
# Fetched: Train to Busan
# Fetched: Alice in Wonderland
# Fetched: Challengers
# Fetched: Better Man
# Fetched: Howl's Moving Castle
# Fetched: Hacksaw Ridge
# Fetched: Iron Man
# Fetched: Scary Movie
# Fetched: John Wick: Chapter 2
# Fetched: Chikan Densha: OL Kando Kurabe
# Fetched: Female Teacher: In Front of the Students
# Fetched: Transformers: Age of Extinction
# Fetched: Rebel Ridge
# Fetched: Joker
# Fetched: The Equalizer
# Fetched: Puss in Boots: The Last Wish
# Fetched: Man with No Past
# Fetched: Black Panther: Wakanda Forever
# Fetched: Loving Cuba
# Fetched: Cannibal Holocaust
# Fetched: A Delicious Flight
# Fetched: The Twilight Saga: Eclipse
# Fetched: Saiyaara
# Fetched: The Life of Chuck
# Fetched: Kung Fu Panda
# Fetched: Female Instructor's Strange Private Lesson
# Fetched: Edward Scissorhands
# Fetched: Joker: Folie à Deux
# Fetched: Halloween
# Fetched: Phantom
# Fetched: The Dark Knight Rises
# Fetched: The Nun II
# Fetched: Kingdom of the Planet of the Apes
# Fetched: The Roundup: Punishment
# Fetched: It
# Fetched: The Truman Show
# Fetched: The Notebook
# Fetched: How to Train Your Dragon 2
# Fetched: The Amazing Spider-Man
# Fetched: GATAO: Big Brothers
# Fetched: Girl in the Basement
# Fetched: Django Unchained
# Fetched: Stepmom's Desire
# Fetched: The Mummy
# Fetched: Scouts Guide to the Zombie Apocalypse
# Fetched: Scurry
# Fetched: Laura's Toys
# Fetched: Snoopy Presents: A Summer Musical
# Fetched: The Amazing Spider-Man 2
# Fetched: Bullet Train
# Fetched: Exterritorial
# Fetched: The Tomorrow War
# Fetched: Tangled
# Fetched: Murder Company
# Fetched: Avengers: Doomsday
# Fetched: Me Before You
# Fetched: Madagascar
# Fetched: It Chapter Two
# Fetched: No Other Choice
# Fetched: Until Dawn
# Fetched: Up
# Fetched: Borders of Love
# Fetched: Jaws
# Fetched: Almost Cops
# Fetched: Scarface
# Fetched: No Country for Old Men
# Fetched: Boyka: Undisputed IV
# Fetched: My Friend's Mom
# Fetched: Ghosted
# Fetched: Delirium
# Fetched: The Twilight Saga: Breaking Dawn - Part 2
# Fetched: Kontrabida Academy
# Fetched: Erotic Ghost Story III
# Fetched: The Ultimate Life
# Fetched: Hotel Transylvania: Transformania
# Fetched: Good Will Hunting
# Fetched: Smile 2
# Fetched: Initial D: Third Stage
# Fetched: Rita
# Fetched: Land of Bad
# Fetched: The Astronaut
# Fetched: City of God
# Fetched: Buddy's Mom
# Fetched: Vera and the Pleasure of Others
# Fetched: Pinball: The Man Who Saved the Game
# Fetched: Charlie and the Chocolate Factory
# Fetched: Percy Jackson & the Olympians: The Lightning Thief
# Fetched: Meg 2: The Trench
# Fetched: Honey Don't!
# Fetched: Jurassic World
# Fetched: Nymphomaniac: Vol. II
# Fetched: Mean Girls
# Fetched: Deadpool
# Fetched: The Unspeakable Act
# Fetched: Toy Story 4
# Fetched: Kayara
# Fetched: A Quiet Place Part II
# Fetched: Immaculate
# Fetched: How to Train Your Dragon
# Fetched: 12 Angry Men
# Fetched: Obsessed
# Fetched: Soul Suburbia
# Fetched: Roofman
# Fetched: Mad Max: Fury Road
# Fetched: Long Distance
# Fetched: Shrek Forever After
# Fetched: Sexual Chronicles of a French Family
# Fetched: Despicable Me
# Fetched: That's Roman Porno: Smile of Goddesses
# Fetched: Ziam
# Fetched: A Nightmare on Elm Street
# Fetched: Devara: Part 1
# Fetched: Scarlet Innocence
# Fetched: The Crow
# Fetched: Asylum: Twisted Horror and Fantasy Tales
# Fetched: Boogie Nights
# Fetched: Flower & Snake: Zero
# Fetched: Heretic
# Fetched: Love Don't Co$t a Thing
# Fetched: Thor: Love and Thunder
# Fetched: Cars 3
# Fetched: Violet
# Fetched: The Twilight Saga: Breaking Dawn - Part 1
# Fetched: Organ Child
# Fetched: Now You See Me
# Fetched: Sisu
# Fetched: Love for Sale
# Fetched: War of the Worlds
# Fetched: Aquaman and the Lost Kingdom
# Fetched: Where Hope Grows
# Fetched: Shutter Island
# Fetched: xXx: Return of Xander Cage
# Fetched: Sketch
# Fetched: Toy Story 4
# Fetched: Five Nights at Freddy's
# Fetched: Red, White & Royal Blue
# Fetched: Whiplash
# Fetched: 10 Things I Hate About You
# Fetched: Dungeons & Dragons: Honor Among Thieves
# Fetched: The Terminator
# Fetched: The Incredible Hulk
# Fetched: Real Steel
# Fetched: Migration
# Fetched: Sing 2
# Fetched: Guns Up
# Fetched: Sticky
# Fetched: The Woman King
# Fetched: Pacific Rim
# Fetched: Deuces Wild
# Fetched: Fit to Kill
# Fetched: Civil War
# Fetched: Hotel Transylvania
# Fetched: The Princess and the Frog
# Fetched: Mickey 17
# Fetched: Catch Me If You Can
# Fetched: Schindler's List
# Fetched: Inklings
# Fetched: Megamind
# Fetched: Raiders!: The Story of the Greatest Fan Film Ever Made
# Fetched: The Equalizer 3
# Fetched: Your Name.
# Fetched: Encanto
# Fetched: The Children of the Century
# Fetched: Cars 2
# Fetched: Fate/stay night: Heaven's Feel III. Spring Song
# Fetched: WALL·E
# Fetched: Sirāt
# Fetched: Ted 2
# Fetched: Beauty and the Beast
# Fetched: Oldboy
# Fetched: Venom
# Fetched: How to Train Your Dragon: The Hidden World
# Fetched: Perfect Blue
# Fetched: My Hero Academia: You're Next
# Fetched: Mickey 17
# Fetched: Operation Fortune: Ruse de Guerre
# Fetched: The Mask
# Fetched: The Green Dinosaur
# Fetched: Exorcismo: The Transgressive Legacy of Clasificada 'S'
# Fetched: Fantastic Four: Rise of the Silver Surfer
# Fetched: A Quiet Place: Day One
# Fetched: Look Back
# Fetched: Thor
# Fetched: Gran Turismo
# Fetched: Ritual
# Fetched: Grown Ups
# Fetched: The Adolescent
# Fetched: Elevator Lady
# Fetched: Kingdom of Heaven
# Fetched: Sin City: A Dame to Kill For
# Fetched: The Emperor's New Groove
# Fetched: AlarumFetched: The Thursday Murder Club
#
# Fetched: Prometheus
#
# Total de filmes buscados: 600

# %% [markdown]
# ### Passo 3. Gerar as dataframes finais para a camada bronze
#
# Alguns dos campos retornados são arrays de objetos. Esses irão se tornar dataframes separadas, interligadas pelo ID do filme. Em seguida cada uma dessas dataframes, se tornarão um csv para a camada bronze (raw data).
#
# Os campos identificados como array são:
# 1. `genres`
# 2. `production_companies`
# 3. `production_countries`
# 4. `spoken_languages`
#
# Nesse contexto, os CSVs de saída dessa extração serão:
# 1. movies.csv
# 2. genres.csv
# 3. production_companies.csv
# 4. production_countries.csv
# 5. spoken_languages.csv
#
# A chave extrangeira que une cada um desses artefatos, é o ID do filme. Para que isso seja garantido, será adicionada uma coluna `movie_id` em cada nos demais CSVs (com exceção de movies.csv por ser o artefato "base").

# %%
array_fields = ["genres", "production_companies", "production_countries", "spoken_languages"]
regular_keys = [key for key in movie_detail_data[0] if key not in array_fields]

regular_movie_fields = []

for movie in movie_detail_data:
    current_movie = {k: v for k, v in movie.items() if k not in array_fields}
    regular_movie_fields.append(current_movie)
    
movie_detail_df = pd.DataFrame(regular_movie_fields)

# %%
array_fields_df = {}

for key in array_fields:
    current_df = pd.json_normalize(
        data=movie_detail_data,
        record_path=key,
        meta=['id'],
        record_prefix=f'{key}_'
    )
    current_df = current_df.rename(columns={'id': 'movie_id', f'{key}_id': 'id'})
    array_fields_df[f'{key}_df'] = current_df
    
    
genres_df = array_fields_df['genres_df']
production_companies_df = array_fields_df['production_companies_df']
production_countries_df = array_fields_df['production_countries_df']
spoken_languages_df = array_fields_df['spoken_languages_df']

# %% [markdown]
# ### Passo 4. Salvar os CSVs na camada bronze
#
# Nesse momento existem 5 dataframes, que serão salvas em arquivos CSVs na camada bronze da seguinte forma:
#
# |Dataframe|Descrição|Arquivo de saída|
# |---|---|---|
# |movie_detail_df|Dataframe principal com os dados de detalhes de filmes|movies.csv|
# |genres_df|Dataframe com dados de gênero dos filmes|genres.csv|
# |production_companies_df|Dataframe com dados de produtoras de filmes|production_companies.csv|
# |production_countries_df|Dataframe com dados de países da produção dos filmes|production_countries.csv|
# |spoken_languages_df|Dataframe com os idiomas falados para cada filme|spoken_languages.csv|

# %%
movie_detail_df.to_csv('bronze/movies.csv', index=False)
genres_df.to_csv('bronze/genres.csv', index=False)
production_companies_df.to_csv('bronze/production_companies.csv', index=False)
production_countries_df.to_csv('bronze/production_countries.csv', index=False)
spoken_languages_df.to_csv('bronze/spoken_languages.csv', index=False)

# %% [markdown]
# ## 3. Ferramentas e Bibliotecas utilizadas
#
# | Ferramenta | Uso no Notebook |
# | :--- | :--- |
# | **Python `requests`** | Responsável por todas as chamadas HTTP para a API do TMDB. |
# | **JSON** | Manipulação e *parsing* das respostas da API, que são formatadas em JSON. |
# | **Pandas** | Estruturação e armazenamento dos dados extraídos em formato DataFrame. |
