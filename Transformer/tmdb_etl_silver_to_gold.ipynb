# %% [markdown]
# # Fluxo ETL de dados da camada Silver para camada Gold
#
# ## Introdução
#
# Na camada Silver (lakehouse), os dados estão agregados e podem ser atualizados constantemente. Por consistir em uma única tabela, a pipeline irá quebrar os dados nas tabelas fato e dimensão para ingestão no Data Warehouse. A documentação das tabelas no schema `warehouse` está disponível no arquivo [GOLD_MER_DER_DLD.pdf](https://github.com/Eric-chagas/film-data-analytics/blob/main/DataLayer/gold/Gold_MER_DER_DLD.pdf). Nessa pipeline serão realizadas as seguintes operações:
#
# 1. **Ingestão dos dados do lakehouse**: Os dados serão lidos diretamente do banco de dados, da tabela `lakehouse.film_lakehouse` para um dataframe no pyspark
# 2. **Criação das entidades**: Os dados da camada silver serão quebrados em entidades fato e dimensão, para que sejam inseridos no warehouse e possam ser feitas queries de business analytics
# 3. **Inserção dos dados no schema data warehouse**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, year, month, dayofmonth, explode, arrays_zip, col, trim, ltrim, lit, count, isnan, to_timestamp, row_number
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, BooleanType, DateType, LongType, TimestampType
from pyspark.sql.window import Window
import time, os, shutil
import psycopg2

# Inicio sessão spark
jar_path = os.path.abspath("../postgresql-42.7.8.jar")
spark = SparkSession.builder.appName("tmdbEtlSilverToGold") \
                            .config("spark.jars", jar_path) \
                            .config("spark.driver.memory", "4g") \
                            .config("spark.executor.memory", "4g") \
                            .getOrCreate()
                            
spark.sparkContext.setLogLevel("ERROR")

# %% [markdown]
# ### 1. Ingestão dos dados do lakehouse
#
# Definição dos schemas das tabelas e Ingestão dos dados do banco.

# %% [markdown]
# ## Configuração do banco

# %%
DB_CONFIG = {
    "user": os.environ.get("DB_USER") or "postgres",
    "password": os.environ.get("DB_PASSWORD") or "secret",
    "host": os.environ.get("DB_HOST") or "localhost",
    "port": os.environ.get("DB_PORT") or "5432",
    "db_name": os.environ.get("DB_NAME") or "postgres",
    "driver": "org.postgresql.Driver"
}

jdbc_url = f"jdbc:postgresql://{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['db_name']}"
jdbc_properties = {
    "user": DB_CONFIG["user"],
    "password": DB_CONFIG["password"],
    "driver": DB_CONFIG["driver"]
}

# %%
lakehouse_schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("title", StringType(), True),
    StructField("vote_average", FloatType(), True),
    StructField("vote_count", IntegerType(), True),
    StructField("status", StringType(), True),
    StructField("release_date", DateType(), True),
    StructField("revenue", IntegerType(), True),
    StructField("runtime", IntegerType(), True),
    StructField("adult", BooleanType(), True),
    StructField("backdrop_path", StringType(), True),
    StructField("budget", IntegerType(), True),
    StructField("homepage", StringType(), True),
    StructField("imdb_id", StringType(), True),
    StructField("original_language", StringType(), True),
    StructField("original_title", StringType(), True),
    StructField("overview", StringType(), True),
    StructField("popularity", FloatType(), True),
    StructField("poster_path", StringType(), True),
    StructField("tagline", StringType(), True),
    StructField("genre", StringType(), True),
    StructField("production_company", StringType(), True),
    StructField("production_country", StringType(), True),
    StructField("spoken_language", StringType(), True)
])

dim_gen_schema = StructType([
    StructField("GEN_SRK", IntegerType(), True),
    StructField("NM_GEN", StringType(), True)
])

dim_prd_com_schema = StructType([
    StructField("COM_SRK", IntegerType(), True),
    StructField("NM_PRD_COM", StringType(), True)
])

dim_cnt_schema = StructType([
    StructField("CNT_SRK", IntegerType(), True),
    StructField("NM_PRD_CNT", StringType(), True)
])

dim_spk_lan_schema = StructType([
    StructField("LAN_SRK", IntegerType(), True),
    StructField("NM_SPK_LAN", StringType(), True)
])

dim_dat_schema = StructType([
    StructField("DAT_SRK", IntegerType(), True),
    StructField("FUL_DAT", DateType(), True),
    StructField("ANO", IntegerType(), True),
    StructField("MES", IntegerType(), True),
    StructField("DIA", IntegerType(), True)
])

dim_sta_schema = StructType([
    StructField("STA_SRK", IntegerType(), True),
    StructField("NM_STA", StringType(), True)
])

movie_gen_bridge_schema = StructType([
    StructField("MOV_SRK", IntegerType(), True),
    StructField("GEN_SRK", IntegerType(), True)
])

movie_prd_com_bridge_schema = StructType([
    StructField("MOV_SRK", IntegerType(), True),
    StructField("COM_SRK", IntegerType(), True)
])

movie_cnt_bridge_schema = StructType([
    StructField("MOV_SRK", IntegerType(), True),
    StructField("CNT_SRK", IntegerType(), True)
])

movie_spk_lan_bridge_schema = StructType([
    StructField("MOV_SRK", IntegerType(), True),
    StructField("LAN_SRK", IntegerType(), True)
])

jdbc_string = f"jdbc:postgresql://localhost:5432/{DB_CONFIG["db_name"]}"
table_name = "lakehouse.film_lakehouse"

lakehouse_df = spark.read.jdbc(
    url=jdbc_string,
    table=table_name,
    properties=DB_CONFIG
)

# %% [markdown]
# ### 2. Criação das entidades
#
# Quebra dos dados do lakehouse nas dataframes dedicadas de fato e dimensão. Para isso serão feitas as seguintes operações:
#
# 1. Quebra das colunas `genres`, `production_companies`, `production_countries` e `spoken_languages` em dataframes separados
# 2. Criação da dataframe final fato
# 3. Inserção no banco nas tabelas do DW

# %% [markdown]
# #### Funções de pesquisa e inserção no banco
#
# As funções abaixo são usadas para garantir consistência referencial durante o processo de carga da camada Gold.
# Elas executam consultas diretas no banco para verificar se uma linha já existe antes da inserção — especialmente importante em dimensões e tabelas bridge, onde não podem existir duplicidades na combinação de chaves.
#
# Além disso, essas funções são responsáveis por inserir novos registros quando necessário e retornar a surrogate key (SRK) gerada automaticamente pelo banco.
# Isso permite que a tabela Fato de Filmes referencie corretamente todas as dimensões (incluindo bridge tables), sempre utilizando as chaves substitutas reais geradas no SGBD, mantendo integridade e alinhamento com o DDL.
#
# Essas funções, portanto:
#
# Evitam duplicidade de registros em dimensões e bridges.
#
# Garantem que cada relacionamento receba sua chave substituta correta.
#
# Asseguram que a tabela fato tenha foreign keys válidas.
#
# Mantêm coerência entre os dados gerados pelo PySpark e a modelagem física real no banco.

# %%
def pg_conn():
    return psycopg2.connect(
        dbname=DB_CONFIG["db_name"],
        user=DB_CONFIG["user"],
        password=DB_CONFIG["password"],
        host=DB_CONFIG["host"],
        port=DB_CONFIG["port"]
    )

def run_sql(sql, commit=True):
    conn = pg_conn()
    cur = conn.cursor()
    cur.execute(sql)
    if commit:
        conn.commit()
    cur.close()
    conn.close()

def write_staging_df(df, staging_tbl):
    """
    Write a dataframe to a staging table (overwrite).
    staging_tbl should be "data_warehouse.stg_xxx"
    """
    df.write \
      .format("jdbc") \
      .option("url", jdbc_url) \
      .option("dbtable", staging_tbl) \
      .option("user", DB_CONFIG["user"]) \
      .option("password", DB_CONFIG["password"]) \
      .option("driver", DB_CONFIG["driver"]) \
      .mode("overwrite") \
      .save()

# %% [markdown]
# ##### Criação dos DataFrames de dimensão para tabelas staging
# 1. DIM_DAT
# 2. DIM_STA
# 3. DIM_GEN
# 4. DIM_PRD_COM
# 5. DIM_CNT
# 6. DIM_SPK_LAN

# %%
dim_gen_stg_df = (
    lakehouse_df
    .select(
        col("id").alias("FK_MOV_NK"),
        col("genre").alias("NM_GEN")
    )
    .filter(col("NM_GEN").isNotNull() & (col("NM_GEN") != ""))
    .distinct()
)

dim_prd_com_stg_df = (
    lakehouse_df
    .select(
        col("id").alias("FK_MOV_NK"),
        col("production_company").alias("NM_PRD_COM")
    )
    .filter(col("NM_PRD_COM").isNotNull() & (col("NM_PRD_COM") != ""))
    .distinct()
)

dim_cnt_stg_df = (
    lakehouse_df
    .select(
        col("id").alias("FK_MOV_NK"),
        col("production_country").alias("NM_PRD_CNT")
    )
    .filter(col("NM_PRD_CNT").isNotNull() & (col("NM_PRD_CNT") != ""))
    .distinct()
)

dim_spk_lan_stg_df = (
    lakehouse_df
    .select(
        col("id").alias("FK_MOV_NK"),
        col("spoken_language").alias("NM_SPK_LAN")
    )
    .filter(col("NM_SPK_LAN").isNotNull() & (col("NM_SPK_LAN") != ""))
    .distinct()
)

dim_status_stg_df = (
    lakehouse_df
    .select(
        col("status").alias("NM_STA")
    )
    .filter(col("NM_STA").isNotNull() & (col("NM_STA") != ""))
    .distinct()
)

dim_date_stg_df = (
    lakehouse_df
    .select(
        col("release_date").alias("DT_FULL")
    )
    .filter(col("DT_FULL").isNotNull())
    .distinct()
    .withColumn("ANO", year(col("DT_FULL")))
    .withColumn("MES", month(col("DT_FULL")))
    .withColumn("DIA", dayofmonth(col("DT_FULL")))
)

# %% [markdown]
# #### Escrita das tables de dimensão no data warehouse

# %%
def write_dim(df, table):
    df.write \
        .mode("append") \
        .format("jdbc") \
        .option("url", jdbc_string) \
        .option("dbtable", f"data_warehouse.{table}") \
        .options(**DB_CONFIG) \
        .save()

write_dim(dim_gen_stg_df.select("NM_GEN").distinct(), "DIM_GEN")
write_dim(dim_prd_com_stg_df.select("NM_PRD_COM").distinct(), "DIM_PRD_COM")
write_dim(dim_cnt_stg_df.select("NM_PRD_CNT").distinct(), "DIM_CNT")
write_dim(dim_spk_lan_stg_df.select("NM_SPK_LAN").distinct(), "DIM_SPK_LAN")
write_dim(dim_date_stg_df, "DIM_DAT")
write_dim(dim_status_stg_df.select("NM_STA").distinct(), "DIM_STA")

# %% [markdown]
# #### Leitura das dimensões inseridas com as SRKs geradas automáticamente no banco

# %%
dim_dat = spark.read.jdbc(jdbc_string, "data_warehouse.DIM_DAT", properties={**DB_CONFIG})
dim_sta = spark.read.jdbc(jdbc_string, "data_warehouse.DIM_STA", properties={**DB_CONFIG})

dim_dat.show()
dim_sta.show()

# %% [markdown]
# #### Criação da tabela fato filme
# A tabela fato já é criada com as foreign keys apontando para dimensão status e dimensão data.

# %%
fct_mov_df = (
    lakehouse_df
        .alias("l")
        .join(dim_dat.alias("d"), col("l.release_date") == col("d.DT_FULL"), "left")
        .join(dim_sta.alias("s"), col("l.status") == col("s.NM_STA"), "left")
        .select(
            col("l.id").alias("CD_MOV_NK"),
            col("l.title").alias("NM_TIT"),
            col("l.release_date").alias("DT_REL"),
            col("l.original_title").alias("NM_ORI_TIT"),
            col("l.runtime").alias("QT_RUN"),
            col("l.budget").alias("VL_BDG"),
            col("l.revenue").alias("VL_REV"),
            col("l.popularity").alias("VL_POP"),
            col("l.vote_average").alias("VL_VOT_AVG"),
            col("l.vote_count").alias("QT_VOT_CNT"),
            col("l.overview").alias("TX_OVR"),
            col("l.tagline").alias("TX_TGL"),
            col("l.adult").alias("IN_ADL"),
            col("l.original_language").alias("CD_ORI_LAN"),
            col("d.DAT_SRK"),
            col("s.STA_SRK")
        )
        .distinct()
)

# %%
write_dim(fct_mov_df, "FCT_MOV")

# %% [markdown]
# #### Geração das tabelas ponte

# %% [markdown]
# ##### Extração da tabela fato filmes no banco com o SRK auto-gerado

# %%
fct_mov_df = spark.read.jdbc(
    url=jdbc_string,
    table="data_warehouse.FCT_MOV",
    properties={**DB_CONFIG}
)

fct_mov_df.printSchema()

# %% [markdown]
# ##### Criação das bridge tables com as FKs das tabelas fato e dimensões

# %% [markdown]
# ###### Tabela bridge FATO FILMES e DIMENSÃO GÊNEROS

# %%
dim_gen = spark.read.jdbc(url=jdbc_string, table="data_warehouse.DIM_GEN", properties={**DB_CONFIG})

mov_gen_df = (
    fct_mov_df.join(
        dim_gen_stg_df,
        fct_mov_df["cd_mov_nk"] == dim_gen_stg_df["FK_MOV_NK"]
    )
    .join(dim_gen, "NM_GEN")
    .select(col("mov_srk"), col("gen_srk"))
)

mov_gen_df.where(col("mov_srk") == 68197).show()
write_dim(mov_gen_df, "MOV_GEN")

# %% [markdown]
# ###### Tabela bridge FATO FILMES e DIMENSÃO PROD COMPANIES

# %%
dim_prd_com = spark.read.jdbc(
    url=jdbc_string,
    table="data_warehouse.DIM_PRD_COM",
    properties={**DB_CONFIG}
)

mov_com_df = (
    fct_mov_df
        .join(dim_prd_com_stg_df, fct_mov_df["cd_mov_nk"] == dim_prd_com_stg_df["FK_MOV_NK"])
        .join(dim_prd_com, "NM_PRD_COM")
        .select(col("mov_srk"), col("com_srk"))
)

mov_com_df.show()
write_dim(mov_com_df, "MOV_COM")

# %% [markdown]
# ###### Tabela bridge FATO FILMES e DIMENSÃO PROD COUNTRY

# %%
dim_cnt = spark.read.jdbc(
    url=jdbc_string,
    table="data_warehouse.DIM_CNT",
    properties={**DB_CONFIG}
)

mov_cnt_df = (
    fct_mov_df
        .join(dim_cnt_stg_df, fct_mov_df["cd_mov_nk"] == dim_cnt_stg_df["FK_MOV_NK"])
        .join(dim_cnt, "NM_PRD_CNT")
        .select(col("mov_srk"), col("cnt_srk"))
)

mov_cnt_df.show()
write_dim(mov_cnt_df, "MOV_CNT")

# %% [markdown]
# ###### Tabela bridge FATO FILMES e DIMENSÃO SPOKEN LANGUAGE

# %%
dim_spk_lan = spark.read.jdbc(
    url=jdbc_string,
    table="data_warehouse.DIM_SPK_LAN",
    properties={**DB_CONFIG}
)

mov_lan_df = (
    fct_mov_df
        .join(dim_spk_lan_stg_df, fct_mov_df["cd_mov_nk"] == dim_spk_lan_stg_df["FK_MOV_NK"])
        .join(dim_spk_lan, "NM_SPK_LAN")
        .select(col("mov_srk"), col("lan_srk"))
)

mov_lan_df.show()
write_dim(mov_lan_df, "MOV_LAN")
